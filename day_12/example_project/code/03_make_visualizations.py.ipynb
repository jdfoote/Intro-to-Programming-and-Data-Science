# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/purdue_tweets.csv')

plot = df.plot.scatter(x='followers', y = 'favorite_count')

plt.savefig('../paper/figures/followers_favorite_scatter.png')
