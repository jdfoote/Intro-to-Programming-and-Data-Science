# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="ticks") # There are a few options for the style for seaborn: 
# white, dark, whitegrid, darkgrid, ticks

# %%
iris = sns.load_dataset("iris")

# %% [markdown]
# ### Exercise 1
#
# Visualize the distribution of another variable in the iris dataset

# %%
sns.displot(iris.petal_length, kde=True)

# %% [markdown]
# ### Exercise 2
#
# Plot a boxplot of the tip size by the size of the party.

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxplot(y = 'tip', x = 'size', data = tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ### Exercise 3
#
# Take your code from Exercise 2, and color the boxplots by the gender of the tipper.

# %%
sns.boxplot(y = 'tip', x = 'size', hue = 'sex', data = tips)
# Out:
# <AxesSubplot:xlabel='size', ylabel='tip'>

# %% [markdown]
# ### Exercise 4
#
# Plot a swarm plot of the bill amount by the size of the party.

# %%
sns.set(rc={"figure.figsize":(18, 4)}) #width=8, height=4
sns.swarmplot(y = 'total_bill', x = 'size', size=5, data = tips);

# %% [markdown]
# ### Exercise 5
#
# Now take your swarm plot and make a facet for each day of the week.
# Hint: To make it look nice, you need to figure out how to wrap it.

# %%
sns.catplot(y = 'total_bill', x = 'size', col="day", col_wrap=2, kind='swarm', data = tips);

# %% [markdown]
# ### Exercise 6
#
# Come up with your own question about this dataset. Then, create a visualization that sheds light on that question and make an argument about how it helps to answer the question.

# %%
# Relationship between tip and day of week
sns.barplot(x='day', y = 'tip', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %%
sns.catplot(x='day', y='tip', col='sex', data=tips);

# %%
sns.barplot(y='tip', x='day', hue='sex', data=tips);

# %%
sns.lineplot(x='day',y='tip', hue='sex', data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip'>

# %% [markdown]
# ### Exercise 7
#
# Load the `diamonds` dataset from `sns` and do the same thing: come up with a question about it and create a visualization that helps to answer it.

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.set(rc={"figure.figsize":(5, 5)})
sns.scatterplot(x='carat', y='price', hue='color', data=diamonds);

# %%
sns.lmplot(x='carat', y='price', hue='cut', col='clarity', col_wrap = 2, palette='viridis', data=diamonds);

# %%
sns.lmplot(x='carat', y='price', hue='clarity', col='cut', col_wrap = 2, palette='viridis', data=diamonds);

# %%
# Price by carat and color

sns.lmplot(x='table', y='price', hue='color', order=2, scatter=False, data=diamonds);

# %%
sns.displot(x='carat', y='price', col='color', col_wrap=2, binwidth=(.8,.2), data=diamonds);
